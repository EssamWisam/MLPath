# %% [markdown]
# In this file, the pipeline using the GLCM features and the GB model is established and ran. This file will import functions from the Data Preperation and Feature Extraction Stages. The functions pertaining to the model will come either from libraries or from the Model Implementation stage.
#
# This file is mainly responsible of the experimentation stage of the MLOPs lifecycle. The experimentation stage is where the model is validated and tuned to achieve the best results.
